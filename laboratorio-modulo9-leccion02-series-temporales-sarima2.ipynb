# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>
#
#
# # Laboratorio: Análisis y Modelado de Series Temporales con SARIMAX
#
# En este laboratorio, practicarás el análisis y modelado de series temporales utilizando el modelo SARIMAX.
# Objetivos del laboratorio
#
# - Analizar series temporales:
#
#     - Identificar tendencias, estacionalidad y posibles rupturas estructurales en los datos.
#
#     - Verificar la estacionaridad de la serie mediante pruebas estadísticas y visuales.
#
#     - Realizar análisis de autocorrelación (ACF) y autocorrelación parcial (PACF).
#
# - Modelar la serie temporal:
#
#     - Ajustar un modelo SARIMAX adecuado para los datos proporcionados.
#
#     - Evaluar los resultados del modelo e interpretar los parámetros obtenidos.
#
# - Interpretar gráficas y resultados:
#
#     - Explicar de forma detallada el significado de las gráficas y resultados generados durante cada etapa del análisis.
#
# # Instrucciones
#
# - Parte 1: Carga y exploración inicial de los datos
#
#     - Descarga el conjunto de datos proporcionado, que contiene una serie temporal de valores relacionados con ventas mensuales de una empresa ficticia durante los últimos 5 años.
#
#     - Realiza una exploración inicial:
#
#         - Gráfica la serie temporal completa para identificar posibles tendencias y estacionalidades.
#
#         - Comenta tus observaciones iniciales sobre los patrones que encuentres.
#
# - Parte 2: Estacionaridad
#
#
#     - Evalúa si la serie es estacionaria:
#
#     - Aplica el test de Dickey-Fuller aumentado (ADF).
#
#     - Si es necesario, realiza transformaciones (diferenciación o logaritmos) para convertir la serie en estacionaria.
#
#     - Genera una gráfica comparativa que muestre la serie original y la transformada, indicando las diferencias visuales.
#
#     - Escribe una interpretación de los resultados del test ADF y de la gráfica.
#
# - Parte 3: Análisis de autocorrelaciones
#
#
#     - Genera los gráficos de ACF (Autocorrelation Function) y PACF (Partial Autocorrelation Function).
#
#     - Identifica:
#
#         - El orden de diferenciación necesario (si aún no lo has hecho).
#
#         - Los posibles valores para los parámetros p y q del modelo SARIMAX.
#
#     - Explica qué indican las autocorrelaciones encontradas y cómo las utilizarás para definir los parámetros del modelo.
#
# - Parte 4: Ajuste del modelo SARIMAX
#
#
#     - Ajusta un modelo SARIMAX utilizando los parámetros identificados.
#
#     - Evalúa el ajuste:
#
#         - Observa los residuos del modelo.
#
#         - Verifica si cumplen las condiciones de ruido blanco mediante análisis visual y pruebas estadísticas.
#
#     - Ajusta el modelo si es necesario, iterando sobre los parámetros.
#
# - Parte 5: Interpretación y predicción
#
#
#     - Interpreta los coeficientes estimados del modelo (incluyendo estacionalidad y efectos externos si aplican).
#
#     - Genera una predicción para los próximos 12 meses.
#
#     - Gráfica las predicciones junto con la serie temporal original.
#
#     - Comenta sobre:
#
#         - La calidad de las predicciones.
#
#         - La utilidad del modelo para la toma de decisiones.

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Importar las clases
# -----------------------------------------------------------------------
from src import soporte_sarima as se

# Configuraciones
# -----------------------------------------------------------------------
pd.options.display.float_format = '{:.0f}'.format
# %load_ext autoreload
# %autoreload 2
from datetime import datetime

# %%
df = pd.read_csv('datos/truck_sales.csv')
df.head()
# Out:
#   Month-Year  Number_Trucks_Sold
# 0     03-Jan                 155
# 1     03-Feb                 173
# 2     03-Mar                 204
# 3     03-Apr                 219
# 4     03-May                 223

# %%
# Convertir la columna 'Year-Month' a formato de fecha 
df["Month-Year"] = pd.to_datetime(df["Month-Year"], format="%y-%b")
df.head()
# Out:
#   Month-Year  Number_Trucks_Sold
# 0 2003-01-01                 155
# 1 2003-02-01                 173
# 2 2003-03-01                 204
# 3 2003-04-01                 219
# 4 2003-05-01                 223

# %%
df.head()
# Out:
#   Month-Year  Number_Trucks_Sold
# 0 2003-01-01                 155
# 1 2003-02-01                 173
# 2 2003-03-01                 204
# 3 2003-04-01                 219
# 4 2003-05-01                 223

# %%
df.set_index('Month-Year', inplace=True)
df.index.name = "Date"
df.head()
# Out:
#             Number_Trucks_Sold
# Date
# 2003-01-01                 155
# 2003-02-01                 173
# 2003-03-01                 204
# 2003-04-01                 219
# 2003-05-01                 223

# %%
# vamos a convertir la columna de "Date" a datetime y crear nuevas columnas para hacer las visualizaciones previas para el Analisis Exploratorio
df_copia = df.copy().reset_index()
df_copia["Date"] = pd.to_datetime(df_copia["Date"])
df_copia["Month"] = df_copia["Date"].dt.month_name()
df_copia["Year"] = df_copia["Date"].dt.year
df_copia.head()
# Out:
#         Date  Number_Trucks_Sold     Month  Year
# 0 2003-01-01                 155   January  2003
# 1 2003-02-01                 173  February  2003
# 2 2003-03-01                 204     March  2003
# 3 2003-04-01                 219     April  2003
# 4 2003-05-01                 223       May  2003

# %%
df_copia["Month"] = df_copia["Date"].dt.month_name()
df_copia["Year"] = df_copia["Date"].dt.year
df_copia.head()
# Out:
#         Date  Number_Trucks_Sold     Month  Year
# 0 2003-01-01                 155   January  2003
# 1 2003-02-01                 173  February  2003
# 2 2003-03-01                 204     March  2003
# 3 2003-04-01                 219     April  2003
# 4 2003-05-01                 223       May  2003

# %%
df
# Out:
#             Number_Trucks_Sold
# Date
# 2003-01-01                 155
# 2003-02-01                 173
# 2003-03-01                 204
# 2003-04-01                 219
# 2003-05-01                 223
# ...                        ...
# 2014-08-01                 933
# 2014-09-01                 704
# 2014-10-01                 639
# 2014-11-01                 571
# 2014-12-01                 666
#
# [144 rows x 1 columns]

# %%
# instanciamos la clase
analisis_st = se.TimeSeriesAnalysis(df_copia, temporal_column="Date", value_column="Number_Trucks_Sold")

analisis_st.exploracion_datos()
# Out:
# El número de filas es 144 y el número de columnas es 3
#
# ----------
#
# No hay duplicados
#
# ----------
#
# No hay valores nulos
#
# ----------
#
# Estadísticas de las variables numéricas:
#                     count  mean  std  min  25%  50%  75%  max
# Number_Trucks_Sold    144   429  189  152  274  406  560  958
# Year                  144  2008    3 2003 2006 2008 2011 2014

# %%
# comprobamos que sea una serie continua
analisis_st.comprobar_serie_continua()
# Out:
# La serie temporal es continua, no faltan meses.

# %%
# visualizamos a ver si tenemos tendencia en nuestros datos
analisis_st.graficar_serie()

# %%
# visualizamos la media movil
analisis_st.graficar_media_movil(window=12)

# %%
# vamos a ver si nuestros datos son estacionales
analisis_st.detectar_estacionalidad()

# %%
# Graficar ACF y PACF
analisis_st.graficar_acf_pacf(lags=40)

# %%
# Prueba de estacionariedad
analisis_st.prueba_estacionariedad()
# Out:
# ADF Statistic: 1.1158932574252591
# p-value: 0.9953500083802601
# Valores Críticos:
# 1%: -3.482087964046026
# 5%: -2.8842185101614626
# 10%: -2.578864381347275
# No podemos rechazar la hipótesis nula. La serie NO es estacionaria.

# %%
# lo primero que vamos a hacer es dividir los datos en test y train, pero ahora no podemos hacerlo de forma aleatoria ya que sino perderíamos la serie temporal
train_size = int(0.7 * len(df))
y_train, y_test = df[:train_size], df[train_size:]

# %%
sarima = se.SARIMAModel()

# Definir los rangos para los parámetros
p_range = range(12)
q_range = range(12)
seasonal_order_ranges = (
    range(2),  # P
    range(2),  # D
    range(2),  # Q
    [12]       # S
)

# Generar parámetros
parametros = sarima.generar_parametros(p_range, q_range, seasonal_order_ranges)
parametros[:5] # Ver algunas combinaciones
# Out:
# [(0, 0, (0, 0, 0, 12)),
#  (0, 0, (0, 0, 1, 12)),
#  (0, 0, (0, 1, 0, 12)),
#  (0, 0, (0, 1, 1, 12)),
#  (0, 0, (1, 0, 0, 12))]

# %%
# Evaluar modelos
results_df = sarima.evaluar_modelos(y_train, y_test, parametros, diferenciacion=1, df_length=len(df), variable="Number_Trucks_Sold")

# Ordenar resultados por RMSE
results_df = results_df.sort_values(by="RMSE", ascending=True)
results_df.head()
# Out:
#   0%|          | 0/1152 [00:00<?, ?it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   0%|          | 2/1152 [00:00<01:15, 15.30it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   0%|          | 4/1152 [00:00<01:25, 13.44it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|          | 6/1152 [00:00<01:30, 12.63it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|          | 8/1152 [00:00<02:01,  9.45it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|          | 10/1152 [00:00<01:49, 10.39it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|          | 12/1152 [00:01<01:58,  9.60it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|          | 14/1152 [00:01<02:16,  8.34it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|▏         | 15/1152 [00:01<02:12,  8.59it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   1%|▏         | 16/1152 [00:01<02:52,  6.57it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 18/1152 [00:02<02:23,  7.89it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 20/1152 [00:02<02:25,  7.78it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 21/1152 [00:02<02:26,  7.70it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 22/1152 [00:02<02:55,  6.45it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 23/1152 [00:02<02:54,  6.47it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 24/1152 [00:03<04:19,  4.35it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 25/1152 [00:03<03:42,  5.07it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 26/1152 [00:03<04:01,  4.65it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 27/1152 [00:03<03:27,  5.42it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   2%|▏         | 28/1152 [00:04<04:30,  4.16it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 29/1152 [00:04<04:21,  4.29it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 30/1152 [00:04<05:35,  3.35it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 31/1152 [00:04<04:52,  3.83it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 32/1152 [00:05<05:46,  3.24it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 33/1152 [00:05<04:50,  3.85it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 34/1152 [00:05<04:53,  3.81it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 36/1152 [00:06<04:14,  4.39it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 37/1152 [00:06<04:22,  4.25it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   3%|▎         | 38/1152 [00:06<05:46,  3.21it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 39/1152 [00:07<05:11,  3.57it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   3%|▎         | 40/1152 [00:07<06:02,  3.07it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▎         | 41/1152 [00:07<05:06,  3.63it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▎         | 42/1152 [00:08<06:06,  3.03it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▎         | 43/1152 [00:08<05:00,  3.69it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 44/1152 [00:08<05:35,  3.30it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 45/1152 [00:08<05:23,  3.42it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   4%|▍         | 46/1152 [00:09<07:29,  2.46it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 47/1152 [00:09<06:31,  2.82it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 48/1152 [00:10<07:09,  2.57it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 49/1152 [00:10<05:43,  3.21it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 50/1152 [00:10<06:17,  2.92it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   4%|▍         | 51/1152 [00:11<05:09,  3.55it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▍         | 52/1152 [00:11<05:12,  3.52it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   5%|▍         | 53/1152 [00:11<05:58,  3.06it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   5%|▍         | 54/1152 [00:12<07:49,  2.34it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▍         | 55/1152 [00:12<06:43,  2.72it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▍         | 56/1152 [00:13<08:08,  2.24it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▍         | 57/1152 [00:13<06:37,  2.75it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▌         | 58/1152 [00:13<07:02,  2.59it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▌         | 59/1152 [00:14<05:52,  3.10it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▌         | 60/1152 [00:14<06:37,  2.75it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   5%|▌         | 61/1152 [00:14<06:54,  2.63it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   5%|▌         | 62/1152 [00:15<08:50,  2.05it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   5%|▌         | 63/1152 [00:15<07:32,  2.40it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 64/1152 [00:16<09:31,  1.90it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 65/1152 [00:16<08:04,  2.24it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 66/1152 [00:17<08:52,  2.04it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 67/1152 [00:17<07:40,  2.36it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 68/1152 [00:18<08:10,  2.21it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   6%|▌         | 69/1152 [00:18<08:13,  2.19it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   6%|▌         | 70/1152 [00:19<10:03,  1.79it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▌         | 71/1152 [00:19<08:38,  2.09it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▋         | 72/1152 [00:20<11:52,  1.52it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   6%|▋         | 73/1152 [00:21<09:47,  1.84it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   6%|▋         | 74/1152 [00:22<11:18,  1.59it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 75/1152 [00:22<09:37,  1.87it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 76/1152 [00:23<10:03,  1.78it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   7%|▋         | 77/1152 [00:23<10:36,  1.69it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   7%|▋         | 78/1152 [00:24<12:55,  1.39it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 79/1152 [00:25<11:00,  1.62it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   7%|▋         | 80/1152 [00:26<16:41,  1.07it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 81/1152 [00:27<13:34,  1.32it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 82/1152 [00:27<13:12,  1.35it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 83/1152 [00:28<11:32,  1.54it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   7%|▋         | 84/1152 [00:29<12:38,  1.41it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   7%|▋         | 85/1152 [00:29<11:54,  1.49it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   7%|▋         | 86/1152 [00:30<13:32,  1.31it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   8%|▊         | 87/1152 [00:31<12:39,  1.40it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   8%|▊         | 88/1152 [00:32<16:39,  1.06it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   8%|▊         | 89/1152 [00:33<14:14,  1.24it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   8%|▊         | 90/1152 [00:34<15:33,  1.14it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   8%|▊         | 91/1152 [00:34<13:03,  1.35it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   8%|▊         | 92/1152 [00:35<13:14,  1.33it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   8%|▊         | 93/1152 [00:36<12:42,  1.39it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   8%|▊         | 94/1152 [00:37<15:49,  1.11it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
#   8%|▊         | 95/1152 [00:37<13:35,  1.30it/s]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#   8%|▊         | 96/1152 [00:39<19:55,  1.13s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# ...
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1128/1152 [19:58<00:56,  2.36s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1129/1152 [19:59<00:42,  1.86s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1130/1152 [20:00<00:38,  1.75s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1131/1152 [20:02<00:35,  1.71s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1132/1152 [20:05<00:44,  2.24s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1133/1152 [20:07<00:38,  2.03s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  98%|█████████▊| 1134/1152 [20:08<00:34,  1.92s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▊| 1135/1152 [20:11<00:38,  2.29s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▊| 1136/1152 [20:15<00:42,  2.63s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▊| 1137/1152 [20:16<00:30,  2.04s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1138/1152 [20:17<00:26,  1.88s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1139/1152 [20:19<00:23,  1.82s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1140/1152 [20:22<00:26,  2.18s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1141/1152 [20:23<00:21,  1.99s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1142/1152 [20:25<00:19,  1.91s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1143/1152 [20:28<00:19,  2.19s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1144/1152 [20:31<00:19,  2.41s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1145/1152 [20:32<00:13,  1.94s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
#  99%|█████████▉| 1146/1152 [20:33<00:11,  1.91s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|█████████▉| 1147/1152 [20:35<00:09,  1.86s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|█████████▉| 1148/1152 [20:39<00:09,  2.39s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|█████████▉| 1149/1152 [20:41<00:06,  2.17s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|█████████▉| 1150/1152 [20:43<00:04,  2.15s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|█████████▉| 1151/1152 [20:46<00:02,  2.46s/it]c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# 100%|██████████| 1152/1152 [20:50<00:00,  1.09s/it]
#        p   q seasonal_order  RMSE
# 615    6   4  (1, 1, 1, 12)    29
# 762    7  11  (0, 1, 0, 12)    29
# 959    9  11  (1, 1, 1, 12)    30
# 951    9  10  (1, 1, 1, 12)    30
# 1143  11  10  (1, 1, 1, 12)    30

# %%
# Ordenar resultados por RMSE
results_df = results_df.sort_values(by="RMSE", ascending=True)
results_df.head()
# Out:
#        p   q seasonal_order  RMSE
# 615    6   4  (1, 1, 1, 12)    29
# 762    7  11  (0, 1, 0, 12)    29
# 959    9  11  (1, 1, 1, 12)    30
# 951    9  10  (1, 1, 1, 12)    30
# 1143  11  10  (1, 1, 1, 12)    30
